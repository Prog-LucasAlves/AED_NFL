# %% [markdown]
# # Análise dos dados(Passing) Coletados

# %% [markdown]
# ### Bibliotecas Utilizadas:

# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização - Gráficos
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore Warning(Avisos)
import warnings

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Carregando os dados

# %%
data = pd.read_csv('../../DATA/DATA_FOR_CLEANING/PASSING/PASSING_CLEAR.csv')

# %% [markdown]
# ### Verificando os dados

# %%
data.head(1)
# Out:
#           Player   Tm  Age Pos   G  GS  Cmp  Att  Cmp%   Yds  TD  TD/G  TD%  \
# 0  Philip Rivers  SDG   29  QB  16  16  357  541  66.0  4710  30  1.88  5.5
#
#    Int  Int/G  Int%   1D  Lng  Y/A  AY/A   Y/C    Y/G   Rate  Sk  Sk/G  SYds  \
# 0   13   0.81   2.4  234   59  8.7   8.7  13.2  294.4  101.8  38  2.38   227
#
#    SYds/G  Sk%  NY/A  ANY/A  Year
# 0   14.19  6.6  7.74   7.77  2010

# %%
data[data['Player'].str.contains('Dak', regex=True)].head()
# Out:
#            Player   Tm  Age Pos   G  GS  Cmp  Att  Cmp%   Yds  TD  TD/G  TD%  \
# 554  Dak Prescott  DAL   23  QB  16  16  311  459  67.8  3667  23  1.44  5.0
# 646  Dak Prescott  DAL   24  QB  16  16  308  490  62.9  3324  22  1.38  4.5
# 738  Dak Prescott  DAL   25  QB  16  16  356  526  67.7  3885  22  1.38  4.2
# 830  Dak Prescott  DAL   26  QB  16  16  388  596  65.1  4902  30  1.88  5.0
# 960  Dak Prescott  DAL   27  QB   5   5  151  222  68.0  1856   9  1.80  4.1
#
#      Int  Int/G  Int%   1D  Lng  Y/A  AY/A   Y/C    Y/G   Rate  Sk  Sk/G  \
# 554    4   0.25   0.9  185   83  8.0   8.6  11.8  229.2  104.9  25  1.56
# 646   13   0.81   2.7  162   81  6.8   6.5  10.8  207.8   86.6  32  2.00
# 738    8   0.50   1.5  206   90  7.4   7.5  10.9  242.8   96.9  56  3.50
# 830   11   0.69   1.8  229   62  8.2   8.4  12.6  306.4   99.7  23  1.44
# 960    4   0.80   1.8   93   58  8.4   8.4  12.3  371.2   99.6  10  2.00
#
#      SYds  SYds/G  Sk%  NY/A  ANY/A  Year
# 554   143    8.94  5.2  7.28   7.86  2016
# 646   185   11.56  6.1  6.01   5.74  2017
# 738   347   21.69  9.6  6.08   6.22  2018
# 830   151    9.44  3.7  7.68   7.84  2019
# 960    66   13.20  4.3  7.72   7.72  2020

# %% [markdown]
# ### Criando Filtro por Jogador

# %%
# Criando o filtro com o nome do jogador escolhido
jogador = 'Dak Prescott'

# Filtrando na base de dados pelo jogador escolhido e salvando em um novo DataFrame
data_escolha = data[data['Player'] == jogador]

# %% [markdown]
# ### Gráfico

# %%
indice = np.arange(len(data['Year']))

plt.style.use('seaborn-pastel')
sns.set(font_scale=1)

figura1, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,3))
figura2, (ax3, ax4) = plt.subplots(1, 2, figsize=(15,3))
figura3, (ax5, ax6) = plt.subplots(1, 2, figsize=(15,3))
figura4, (ax7, ax8) = plt.subplots(1, 2, figsize=(15,3))
figura5, (ax9, ax10) = plt.subplots(1, 2, figsize=(15,3))
figura6, (ax11, ax12) = plt.subplots(1, 2, figsize=(15,3))
figura7, (ax13, ax14) = plt.subplots(1, 2, figsize=(15,3))

# Primeiro bloco de gráficos
sns.barplot(x=data_escolha['Year'], y=data_escolha['Att'], ax=ax1, data=data_escolha)
ax1.axhline(data_escolha['Att'].mean(), label=f"Média - {round(data_escolha['Att'].mean(),2)}", linewidth=3, color='#d62728')
ax1.legend()
ax1.set_title(f'Total de Tentativas de Passe * Ano * {jogador}')

sns.barplot(x=data_escolha['Year'], y=data['Cmp'], ax=ax2, data=data_escolha)
ax2.axhline(data_escolha['Cmp'].mean(), label=f"Média - {round(data_escolha['Cmp'].mean(),2)}", linewidth=3, color='#d62728')
ax2.legend()
ax2.set_title(f'Total de Passes Completos * Ano * {jogador}')

# Segundo bloco de gráficos
sns.barplot(x=data_escolha['Year'], y=data_escolha['Cmp%'], ax=ax3, data=data_escolha)
ax3.axhline(data_escolha['Cmp%'].mean(), label=f"Média - {round(data_escolha['Cmp%'].mean(),2)}", linewidth=3, color='#d62728')
ax3.legend()
ax3.set_title(f'Porcentagem de Passes Completos * Ano * {jogador}')

sns.barplot(x=data_escolha['Year'], y=data_escolha['Yds'], ax=ax4, data=data_escolha)
ax4.axhline(data_escolha['Yds'].mean(), label=f"Média - {round(data_escolha['Yds'].mean(),)}", linewidth=3, color='#d62728')
ax4.legend()
ax4.set_title(f'Total de Jardas - Passe * Ano * {jogador}')

# Terceiro bloco de gráficos
sns.barplot(x=data_escolha['Year'], y=data_escolha['TD'], ax=ax5, data=data_escolha)
ax5.axhline(data_escolha['TD'].mean(), label=f"Média - {round(data_escolha['TD'].mean(),)}", linewidth=3, color='#d62728')
ax5.legend()
ax5.set_title(f'Passes para Touchdowns * Ano * {jogador}')

sns.barplot(x=data_escolha['Year'], y=data_escolha['TD/G'], ax=ax6, data=data_escolha)
ax6.axhline(data_escolha['TD/G'].mean(), label=f"Média - {round(data_escolha['TD/G'].mean(),2)}", linewidth=3, color='#d62728')
ax6.legend()
ax6.set_title(f'Média de Touchdowns por jogo * Ano * {jogador}')

# Quarto bloco de gráficos
sns.barplot(x=data_escolha['Year'], y=data_escolha['Int'], ax=ax7, data=data_escolha)
ax7.axhline(data_escolha['Int'].mean(), label=f"Média - {round(data_escolha['Int'].mean(),2)}", linewidth=3, color='#d62728')
ax7.legend()
ax7.set_title(f'Interceptações de Passes * Ano * {jogador}')

sns.barplot(x=data_escolha['Year'], y=data_escolha['Int/G'], ax=ax8, data=data_escolha)
ax8.axhline(data_escolha['Int/G'].mean(), label=f"Média - {round(data_escolha['Int/G'].mean(),2)}", linewidth=3, color='#d62728')
ax8.legend()
ax8.set_title(f'Média de Interceptações de Passes por jogo * Ano * {jogador}')

# Quinto bloco de gráficos
sns.barplot(x=data_escolha['Year'], y=data_escolha['Y/G'], ax=ax9, data=data_escolha)
ax9.axhline(data_escolha['Y/G'].mean(), label=f"Média - {round(data_escolha['Y/G'].mean(),2)}", linewidth=3, color='#d62728')
ax9.legend()
ax9.set_title(f'Média de Jardas por Jogo * Ano * {jogador}')

sns.barplot(x=data_escolha['Year'], y=data_escolha['Y/A'], ax=ax10, data=data_escolha)
ax10.axhline(data_escolha['Y/A'].mean(), label=f"Média - {round(data_escolha['Y/A'].mean(),2)}", linewidth=3, color='#d62728')
ax10.legend()
ax10.set_title(f'Média de Jardas Ganhas por Tentativa de Passe * Ano * {jogador}')

# Sexto bloco de gráficos
sns.barplot(x=data_escolha['Year'], y=data_escolha['Sk'], ax=ax11, data=data_escolha)
ax11.axhline(data_escolha['Sk'].mean(), label=f"Média - {round(data_escolha['Sk'].mean(),2)}", linewidth=3, color='#d62728')
ax11.legend()
ax11.set_title(f'Quantidade de Sacks * Ano * {jogador}')

sns.barplot(x=data_escolha['Year'], y=data_escolha['Sk/G'], ax=ax12, data=data_escolha)
ax12.axhline(data_escolha['Sk/G'].mean(), label=f"Média - {round(data_escolha['Sk/G'].mean(),2)}", linewidth=3, color='#d62728')
ax12.legend()
ax12.set_title(f'Média de Sacks por Jogo * Ano * {jogador}')

# Setimo bloco de gráficos
sns.barplot(x=data_escolha['Year'], y=data_escolha['SYds'], ax=ax13, data=data_escolha)
ax13.axhline(data_escolha['SYds'].mean(), label=f"Média - {round(data_escolha['SYds'].mean(),2)}", linewidth=3, color='#d62728')
ax13.legend()
ax13.set_title(f'Jardas Perdidas por Sacks * Ano * {jogador}')

sns.barplot(x=data_escolha['Year'], y=data_escolha['SYds/G'], ax=ax14, data=data_escolha)
ax14.axhline(data_escolha['SYds/G'].mean(), label=f"Média - {round(data_escolha['SYds/G'].mean(),2)}", linewidth=3, color='#d62728')
ax14.legend()
ax14.set_title(f'Média de Jardas Perdidas por Sack por Jogo * Ano * {jogador}');

# %% [markdown]
# # Percentual de passes completados(Total)?
#
# - Base de dados de -> 2010 até atual

# %%
df_dados = data.groupby(['Player'])[['Yds','Att','Cmp','TD']].agg(['sum']) #.rename(columns={'sum':'Total de Jardas - 2009|2022','sum':'Total de TD - 2009|2022'})
df_dados.columns = df_dados.columns.get_level_values(0)
df_dados.rename(columns={'Yds':'Total de Jardas',
                        'Att':'Total de Tentativa de Passes',
                        'Cmp':'Passes Completos',
                        'TD':'Total de TDs'}, inplace=True)
df_dados_yds = df_dados.sort_values('Total de Jardas', ascending=False).reset_index()
df_dados_yds['%TP/PC'] = round(df_dados_yds['Passes Completos'] / df_dados_yds['Total de Tentativa de Passes'] * 100,2)


df_dados_yds = df_dados_yds[['Player','Total de Jardas','Total de Tentativa de Passes','Passes Completos','%TP/PC','Total de TDs']].head(15)

df_dados_yds
# Out:
#                 Player  Total de Jardas  Total de Tentativa de Passes  \
# 0            Tom Brady            55618                          7395
# 1            Matt Ryan            55387                          7415
# 2           Drew Brees            49712                          6387
# 3     Matthew Stafford            49304                          6673
# 4        Philip Rivers            48489                          6220
# 5        Aaron Rodgers            48156                          6226
# 6   Ben Roethlisberger            44786                          6032
# 7       Russell Wilson            38501                          4933
# 8          Eli Manning            38379                          5326
# 9          Andy Dalton            36225                          5149
# 10          Joe Flacco            35586                          5336
# 11        Kirk Cousins            34095                          4451
# 12          Derek Carr            33220                          4667
# 13          Cam Newton            32382                          4474
# 14      Ryan Tannehill            31826                          4355
#
#     Passes Completos  %TP/PC  Total de TDs
# 0               4789   64.76           407
# 1               4917   66.31           338
# 2               4445   69.59           369
# 3               4261   63.85           316
# 4               4070   65.43           315
# 5               4088   65.66           401
# 6               3914   64.89           291
# 7               3195   64.77           297
# 8               3302   62.00           241
# 9               3205   62.25           233
# 10              3290   61.66           197
# 11              2976   66.86           232
# 12              3030   64.92           202
# 13              2682   59.95           194
# 14              2797   64.23           205

# %%
# Criando o filtro temporada
temp = 2022

# Filtrando na base de dados pela temporada e salvando em um novo DataFrame
data_tem = data[(data['Year'] == temp) & (data['Cmp'] >= 50)]

# Visualizando
data_tem.tail(30)
# Out:
#                  Player   Tm  Age Pos  G  GS  Cmp  Att  Cmp%   Yds  TD  TD/G  \
# 1161         Geno Smith  SEA   32  QB  7   7  158  215  73.5  1712  11  1.57
# 1162    Trevor Lawrence  JAX   23  QB  7   7  155  246  63.0  1707   9  1.29
# 1163       Kyler Murray  ARI   25  QB  7   7  184  281  65.5  1667   7  1.00
# 1164      Aaron Rodgers  GNB   39  QB  7   7  163  244  66.8  1597  11  1.57
# 1165    Jacoby Brissett  CLE   30  QB  7   7  146  233  62.7  1584   6  0.86
# 1166         Jared Goff  DET   28  QB  6   6  132  212  62.3  1583  11  1.83
# 1167   Matthew Stafford  LAR   34  QB  6   6  160  225  71.1  1576   6  1.00
# 1168         Derek Carr  LVR   31  QB  6   6  134  211  63.5  1520   9  1.50
# 1169        Jalen Hurts  PHI   24  QB  6   6  123  184  66.8  1514   6  1.00
# 1170       Kirk Cousins  MIN   34  QB  6   6  151  228  66.2  1502   9  1.50
# 1171       Carson Wentz  WAS   30  QB  6   6  144  232  62.1  1489  10  1.67
# 1172    Jimmy Garoppolo  SFO   31  QB  6   5  119  185  64.3  1456   9  1.50
# 1173     Russell Wilson  DEN   34  QB  6   6  116  198  58.6  1442   5  0.83
# 1174      Lamar Jackson  BAL   25  QB  7   7  121  197  61.4  1397  13  1.86
# 1185    74   24.67   8.7  6.22   5.07  2022
# 1186    53   10.60   6.6  5.43   5.21  2022
# 1187    39   13.00   4.9  7.32   5.51  2022
# 1188    40   10.00   4.5  5.50   3.43  2022
# 1189    54   13.50   7.3  5.86   5.22  2022
# 1190    32   10.67   6.7  7.52   7.99  2022

# %%
# Selecionando Variáveis
# Top 5 jardas
data_yds = data_tem[['Player', 'Yds']].sort_values(by='Yds', ascending=False).head(5)

# Top 5 TDs
data_tds = data_tem[['Player', 'TD']].sort_values(by='TD', ascending=False).head(5)

# Top 5 passes completos
data_cmp = data_tem[['Player', 'Att', 'Cmp']].sort_values(by='Cmp', ascending=False).head(5)

# Top 5 porcentagem de passes completos
#data_pcmp = data_tem[['Player', 'Cmp%']].sort_values(by='Cmp%', ascending=False).head(5)

print('-----')
print(data_yds.head())
print('-----')
print(data_tds.head())
print('-----')
print(data_cmp.head())
print('-----')
# Out:
# -----
#                Player   Yds
# 1155  Patrick Mahomes  2159
# 1156       Joe Burrow  2097
# 1157   Justin Herbert  2009
# 1158        Matt Ryan  2008
# 1159       Josh Allen  1980
# -----
#                Player  TD
# 1155  Patrick Mahomes  20
# 1159       Josh Allen  17
# 1156       Joe Burrow  15
# 1174    Lamar Jackson  13
# 1157   Justin Herbert  12
# -----
#               Player  Att  Cmp
# 1157  Justin Herbert  308  203
# 1158       Matt Ryan  297  203
# 1160       Tom Brady  296  198
# 1156      Joe Burrow  270  186
# 1163    Kyler Murray  281  184
# -----

# %%
# Configuração dos gráficos
figura1, (ax100, ax101) = plt.subplots(1, 2, figsize=(15,4))
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)

# Primeiro bloco de gráficos
sns.barplot(x=data_yds['Yds'], y=data_yds['Player'], ax=ax100, data=data_yds)
ax100.bar_label(ax100.containers[0], fmt=f'%.0f Yds', padding=-54)
ax100.set_title(f'Top 5 Total de Jardas Temp. 22/23')
ax100.set_xlim(right=2500)

sns.barplot(x=data_tds['TD'], y=data_tds['Player'], ax=ax101, data=data_tds)
ax101.bar_label(ax101.containers[0], fmt=f'%.0f TDs', padding=-42)
ax101.set_title(f'Top 5 Total de Touchdowns Temp. 22/23')
ax101.set_xlim(left=0, right=25)

figura1.tight_layout()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 g = sns.catplot(x='Player', y='Player', hue='', col='',
#       2 estimator=np.sum, data=data_cmp, palette="RdBu", kind="bar", height=7, aspect=1, legend=False, ci=None)
#
# File c:\Users\Lucas\anaconda3\envs\AED\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\Lucas\anaconda3\envs\AED\lib\site-packages\seaborn\categorical.py:3792, in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790 p = _CategoricalPlotter()
#    3791 p.require_numeric = plotter_class.require_numeric
# -> 3792 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793 if (
#    3794     order is not None
#    3795     or (sharex and p.orient == "v")
#    3796     or (sharey and p.orient == "h")
#    3797 ):
#    3798     # Sync categorical axis between facets to have the same categories
#    3799     order = p.group_names
#
# File c:\Users\Lucas\anaconda3\envs\AED\lib\site-packages\seaborn\categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input ''
